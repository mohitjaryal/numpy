# %% [markdown]
# # Advance operations uisng Business Examples

# %% [markdown]
# # Data structure: [restaurant_id, 2021, 2022, 2023]
# sales_data = np.array({
#     [1,15000,12000,25000,22000],
#     [2,15000,12000,25000,22000],
#     [3,15000,12000,25000,22000],
#     [4,15000,12000,25000,22000],
#     [5,15000,12000,25000,22000],
# })
