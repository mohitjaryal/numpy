# %% [markdown]
# # Find the shape,size,dimension and data type of the given array

# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
print('Shape :',a.shape)
print('Dimension :',a.shape)
print('Data type :',a.shape)
# Out:
# Shape : (2, 3)
