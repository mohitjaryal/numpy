# %% [markdown]
# # Find the shape,size,dimension and data type of the given array

# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
print('Shape :',a.shape)
print('Size :',a.size)
print('Dimension :',a.ndim)
print('Data type :',a.dtype)
# Out:
# Shape : (2, 3)
# Size : 6
# Dimension : 2
# Data type : int64
