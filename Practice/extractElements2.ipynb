# %% [markdown]
# # Create a 3×3 array and extract:
#  The first row, last column, The element in the second row, third column

# %%
import numpy as np

# %%
arr = np.random.random((3,3))
print('Original array :',arr)
print('1st row :',arr[0])
print('Last column :',arr[:,-1])
# Out:
# Original array : [[0.8594558  0.23547423 0.55583792]
#  [0.17289694 0.30963646 0.08853115]
#  [0.22623118 0.44921221 0.56593364]]
# 1st row : [0.8594558  0.23547423 0.55583792]
# Last column : [0.55583792 0.08853115 0.56593364]
