# %% [markdown]
# # Generate a 3×3 array with random floats between 0 and 1.

# %%
import numpy as np

# %%
arr = np.random.random((3,3))
print('Random array :',arr)
# Out:
# Random array : [[0.55353735 0.0449138  0.67314201]
#  [0.46234792 0.53685342 0.31187925]
#  [0.42146328 0.71339967 0.64599367]]
