# %% [markdown]
# # Create two arrays a = np.array([1,2,3]) and b = np.array([4,5,6]). Perform:
#  addition, subtraction, multiplication, division

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# Addition
print('Addition :', a + b)

# Subtaction
print('Subtraction :',a - b)
# Out:
# Addition : [5 7 9]
# Subtraction : [-3 -3 -3]
