# %% [markdown]
# # Create a 2×5 array filled with a constant value (like 7).

# %%
import numpy as np

# %%
arr = np.full((2,5),7)
print('Array with constant value 7 :',arr)
# Out:
# Array with constant value 7 : [[7 7 7 7 7]
#  [7 7 7 7 7]]
