# %% [markdown]
# # Learning numpy

# %%
import numpy as np

# %% [markdown]
# ## Creating arrays from list

# %%
arr_1d = np.array([1,2,3,4,5])
print('1d array :',arr_1d)

arr_2d = np.array([[1,2,3],[4,5,6]])
print('2d array :',arr_2d)
# Out:
# 1d array : [1 2 3 4 5]
# 2d array : [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## Lists vs array

# %%
import time 
 
start = time.time()
py_pist = [i * 2 for ] 
print('Multiplication :',py_pist * 2)


np_array = np.array([1,2,3])
print('Multiplication :',np_array * 2)
# Out:
# Multiplication : [1, 2, 3, 1, 2, 3]
# Multiplication : [2 4 6]
